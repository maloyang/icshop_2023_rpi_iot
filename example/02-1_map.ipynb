# %% [markdown]
# # 02-1 : 初步感受Python的威力

# %% [markdown]
# ## 快速使用套件，完成一個地圖應用

# %%
import pandas as pd

# %%
# 上傳 bike_data.csv 到 colab的空間
from google.colab import files
uploaded = files.upload()

# %%
url = './bike_data.csv'
df = pd.read_csv(url, encoding='big5')

# %%
df.head()
# Out:
#            站點名稱        緯度         經度  \
# 0  北新竹火車站(新竹高工)  24.80963  120.98351
# 1     明志書院立體停車場  24.80167  120.96576
# 2    十八尖山(新竹高商)  24.79703  120.98755
# 3     清華大學(小吃部)  24.79307  120.99335
# 4   陽明交通大學(大學路)  24.78940  121.00026
#
#                                                   圖片                站點位置
# 0  https://odws.hccg.gov.tw/001/Upload/25/relpic/...       中華路二段2-1號前人行道
# 1  https://odws.hccg.gov.tw/001/Upload/25/relpic/...    西大路317號(停車場前人行道)
# 2  https://odws.hccg.gov.tw/001/Upload/25/relpic/...        博愛街5巷2號對面停車場
# 3  https://odws.hccg.gov.tw/001/Upload/25/relpic/...  光復路二段101號(小吃部左側廣場)
# 4  https://odws.hccg.gov.tw/001/Upload/25/relpic/...      大學路200號(對面人行道)

# %%
# 後續會使用到 folium, geocoder套件，可以安裝如下
# pip install folium
# pip install geocoder

# %%
# 在colab用底下的安裝指令

# !pip install geocoder

# %%
import folium
import geocoder

# %%
# 使用 geocoder 取得特定住址的 GPS 座標
location = geocoder.osm('新竹市').latlng

# %%
location
# Out:
# [24.8066333, 120.9686833]

# %%
m = folium.Map(location=location, zoom_start=16)

# %%
for i, row in df.iterrows():
    try:
        folium.Marker([float(row['緯度']), float(row['經度'])], popup=row['站點名稱']).add_to(m)
    except Exception as e:
        print(e.args)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb0e79b52e4f26309bf22bfe2d0de3a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb0e79b52e4f26309bf22bfe2d0de3a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb0e79b52e4f26309bf22bfe2d0de3a3 = L.map(
#                 &quot;map_bb0e79b52e4f26309bf22bfe2d0de3a3&quot;,
#                 {
#                     center: [24.8066333, 120.9686833],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76cdd549a4b168341235375a444b1a5a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb0e79b52e4f26309bf22bfe2d0de3a3);
#
#
#             var marker_d0f37c2f6744f59cce2a5b9708fbe6d0 = L.marker(
#                 [24.80963, 120.98351],
#                 {}
#             ).addTo(map_bb0e79b52e4f26309bf22bfe2d0de3a3);
#
#
#         var popup_86f42ac5b8e8e66bc5a28aedaad3ebc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db8803de66350f8349fa0812b435f8fe = $(`&lt;div id=&quot;html_db8803de66350f8349fa0812b435f8fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;北新竹火車站(新竹高工)&lt;/div&gt;`)[0];
#                 popup_86f42ac5b8e8e66bc5a28aedaad3ebc5.setContent(html_db8803de66350f8349fa0812b435f8fe);
#
#
#
#         marker_d0f37c2f6744f59cce2a5b9708fbe6d0.bindPopup(popup_86f42ac5b8e8e66bc5a28aedaad3ebc5)
#         ;
#
#
#
#
#             var marker_a62170a6f35eb508740d69e40da36b0e = L.marker(
#                 [24.80167, 120.96576],
#                 {}
#             ).addTo(map_bb0e79b52e4f26309bf22bfe2d0de3a3);
#
#
#         var popup_6ea1d823d2d5587245cd5554f2e4084a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46925219a9e50543ff20df620e7189e7 = $(`&lt;div id=&quot;html_46925219a9e50543ff20df620e7189e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;明志書院立體停車場&lt;/div&gt;`)[0];
#                 popup_6ea1d823d2d5587245cd5554f2e4084a.setContent(html_46925219a9e50543ff20df620e7189e7);
#
#
#
#         marker_a62170a6f35eb508740d69e40da36b0e.bindPopup(popup_6ea1d823d2d5587245cd5554f2e4084a)
#         ;
#
#
#
#
#             var marker_f113c2ad5d9a3fddfb6de19a6b80a06e = L.marker(
#                 [24.79703, 120.98755],
#                 {}
#             ).addTo(map_bb0e79b52e4f26309bf22bfe2d0de3a3);
#
#
#         var popup_c325ace23c5c1bcb9c7bf64a7c1d31d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdaa6c4abfe652a6d3fdf7afc82d6850 = $(`&lt;div id=&quot;html_bdaa6c4abfe652a6d3fdf7afc82d6850&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;十八尖山(新竹高商)&lt;/div&gt;`)[0];
#                 popup_c325ace23c5c1bcb9c7bf64a7c1d31d2.setContent(html_bdaa6c4abfe652a6d3fdf7afc82d6850);
#
#
#
#         marker_f113c2ad5d9a3fddfb6de19a6b80a06e.bindPopup(popup_c325ace23c5c1bcb9c7bf64a7c1d31d2)
#         ;
#
#
#
#
#             var marker_910934ee148ef1a5de1265047116e4d4 = L.marker(
#                 [24.79307, 120.99335],
#                 {}
#             ).addTo(map_bb0e79b52e4f26309bf22bfe2d0de3a3);
#
#
#         var popup_2708051ec6c45473bd38e1402e665e76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_963f7424e1f94fd6ed1a1a89f19edce4 = $(`&lt;div id=&quot;html_963f7424e1f94fd6ed1a1a89f19edce4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;清華大學(小吃部)&lt;/div&gt;`)[0];
#                 popup_2708051ec6c45473bd38e1402e665e76.setContent(html_963f7424e1f94fd6ed1a1a89f19edce4);
#
#
#
#         marker_910934ee148ef1a5de1265047116e4d4.bindPopup(popup_2708051ec6c45473bd38e1402e665e76)
#         ;
#
#
#
#
#             var marker_10cecfb3633a2490cee8cf2f40006dab = L.marker(
#                 [24.7894, 121.00026],
#                 {}
#             ).addTo(map_bb0e79b52e4f26309bf22bfe2d0de3a3);
#
#
#         var popup_c7f590b2f206efdfb7746183dc6e141c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdcac8a149ed29d230db16052c5deb0b = $(`&lt;div id=&quot;html_bdcac8a149ed29d230db16052c5deb0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;陽明交通大學(大學路)&lt;/div&gt;`)[0];
#                 popup_c7f590b2f206efdfb7746183dc6e141c.setContent(html_bdcac8a149ed29d230db16052c5deb0b);
#
#
#
#         marker_10cecfb3633a2490cee8cf2f40006dab.bindPopup(popup_c7f590b2f206efdfb7746183dc6e141c)
#         ;
#
#
#
#
#             var marker_b97dfc8cee31592795bc06f4a83d0403 = L.marker(
#                 [24.78473, 120.99994],
#                 {}
#             ).a
